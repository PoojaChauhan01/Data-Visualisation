# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints=np.array([1,2])
ypoints=np.array([5,10])

plt.plot(xpoints,ypoints)
plt.show()

# %%
xpoints=np.array([1,20])
ypoints=np.array([10,100])
plt.plot(xpoints,ypoints)
plt.show()

# %%
xpoints=np.array([1,6])
ypoints=np.array([4,5])
plt.plot(xpoints,ypoints,'*')
plt.show()

# %%
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,'*''g')
plt.show()

# %%
xpoints=np.array([3,8,1,12])
ypoints=np.array([5,6,7,9])
plt.plot(xpoints,ypoints,marker='*',ms=100,color='red')
plt.show()

# %%
yponits=np.array([3,8,1,10])
plt.plot(ypoints,marker='o',ms=20,mfc='g',mec='k')
plt.show()

# %%
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,linewidth=5)
plt.show()

# %%
y1=np.array([3,8,1,10])
y2=np.array([6,2,5,11])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])

plt.plot(x, y,color="r",linewidth=1)

plt.xlabel("Avarage pluse",fontsize=30,color="red")
plt.ylabel("calorie barger",fontsize=10,color='g')

plt.show()

# %%
x=np.array([80,85,90,95,100,105,115,120,125,154])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.title("spots watch Data")
plt.xlabel("Anerage Plue")
plt.ylabel("calorie burger")

plt.plot(x, y)

plt.grid(color="green")

plt.show()

# %%
### you can use the axis parameter in the grid () function to specify which grid lines to display.


### leagal value are:'x','y',and'both',Default value is 'both'
x= np.array([80,85,90,95,100,105,110,115,120,125])
y =np.array([240,250,260,270,280,290,300,310,320,330])

plt.title("sports watch Data")
plt.xlabel("Average pluse")
plt.ylabel("calorie burger")

plt.plot(x,y)

plt.grid(axis='x')

plt.show()

# %%
###Display only grid lines for the y-axis
x=np.array([80,85,90,95,100,110,105,115,120,125,])
y=np.array([240,250,260,270,280,290,300,310,320,330])

plt.title(" Sports watches data")
plt.xlabel("Average PLuse")
plt.ylabel("calorie burger")
plt.plot(x,y)
plt.grid(axis='y')
plt.show()

# %%
### Set the liine properties of grid 
### you can also set the line properties of the grid,like this:grid
                       ###(color='color',linestyle='linestyle',linewidth=number).
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.title(" Sports watches Data")
plt.xlabel("Average pluse")
plt.ylabel("calories burger")

plt.plot(x,y)

plt.grid(color='hotpink', linestyle='--', linewidth = 1.5 )  
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([5,10,15,20,25])
plt.scatter(x,y)

# %%
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([23,12,45,23,86,103,87,64,78,77,58,56,12])
plt.scatter(x,y)
plt.show()

# %%
#day one,the age and speed of 13 car:
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y)

#day two,the age and speed of 15 cars:
x=np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y=np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x,y)
plt.show()

# %%
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])

plt.barh(x,y,color="green")
plt.show()

# %%
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])

plt.bar(x,y,width=2.2)
plt.show()

# %%
x=np.random.normal(15,5,1000)

# %%
plt.hist(x)
plt.show()

# %%
y=np.array([10,135,25,15,19])
plt.pie(y)
plt.show()

# %%
### Add labels to the pie chat with the label parameter.

### The Label parameter must be an array with one Label for each wedge
y=np.array([10,25,15,10])
mylabels=["cherries","Apples","Bnananas","Dates"]

plt.pie(y,labels=mylabels)
plt.show()

# %%
### As mentioned the default start angle is at the x-axis,but you can change the start angle
### by specifying a startangle parameter.

###The startangle parameter is definrd width an angle in degree,default angle is0:
y=np.array([35,25,25,15])
mylabels=["Apples","Bananas","Cherries","Dates"]

plt.pie(y, labels=mylabels,startangle=180)
plt.show()

# %%
y=np.array([35,25,25,15])
mylabels=["Apples","Bananas","Cherries","Dates"]
myexplode=[0,0.95,0.8,0.2]

plt.pie(y,labels=mylabels,explode=myexplode)
plt.show()

# %%
y=np.array([25,25,25,100])
mylabels=["Apples","Bananas","Cherries","Dates"]
mycolors=["black","hotpink","b","yellow"]

plt.pie(y,labels=mylabels,colors=mycolors,startangle=180)
plt.show()

# %%
y=np.array([35,25,25,15])
#mylabels=["Apples","Bananas","Cherries","Dates"]
plt.pie(y)
plt.legend(labels=mylabels)
plt.show()
